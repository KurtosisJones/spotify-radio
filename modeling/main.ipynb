# %%
# %load_ext autoreload
# %autoreload 2

# %%
## take a sample reduce it
import dotenv
import os
import joblib
import numpy as np
from helper.spotify_api import get_spotify_token, search_track_id_by_name, get_audio_features_by_id
from helper.dimension_reduction import PCA, AutoEncoder
from helper.cluster import Kmeans, Kmedians

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
song_name = "Bohemian Rhapsody"
artist_name = "Queen"
dimension_reduction = "PCA"
dimension = 3
clustering = "KMeans"
clusters = 4
distance = "Euclidean"

dimension_reduction_options = {
    "AutoEncoder":{"key": "auto", "min": 1, "max": 3},
    "PCA":{"key":"pca", "min": 1, "max": 12},
    "Base":{"key":"base"}
}
clustering_options = {
    "KMeans":{"key": "kmeans", "min": 2, "max": 5},
    "KMedians":{"key":"kmedians", "min": 1, "max": 5}
}
distance_options = {
    "Euclidean": {"key": "euclidean"},
    "Manhattan": {"key": "manhattan"}
}

# %%
access_token = get_spotify_token(os.environ["SPOTIFY_ID"], os.environ["SPOTIFY_TOKEN"])

# %%
song_response = search_track_id_by_name(access_token=access_token, song_name=song_name, artist_name=artist_name)
track_id = song_response[1]["id"]

# %%
audio_features = get_audio_features_by_id(access_token=access_token, track_id=track_id)

# %%
audio_features_val = {k: v for k, v in audio_features.items() if k not in ["type", "id", "uri", "track_href", "analysis_url"]}
audio_features_sort = {key: audio_features_val[key] for key in sorted(audio_features_val)}

# %%
np_sample = np.array([v for k, v in audio_features_sort.items()])

# %%
picked_dim = dimension_reduction_options[dimension_reduction]["key"]
picked_clus = clustering_options[clustering]["key"]

# %%
dim_red_model = joblib.load(f"trained/{picked_dim}_c{dimension}/{picked_dim}.pkl")

# %%
reduced_sample = dim_red_model.project(np_sample)

# %%
clustering_model = joblib.load(f"trained/{picked_dim}_c{dimension}/{picked_clus}_c{clusters}/cluster.pkl")

# %%
prediction = clustering_model.predict(reduced_sample.reshape(1, -1))

# %%
arr_data = np.load(f"trained/{picked_dim}_c{dimension}/data.npy")
arr_id = np.load(f"trained/audio_index.npy", allow_pickle=True)
arr_id_reshaped = arr_id.reshape(-1, 1)

# %%
combined_array = np.concatenate((arr_data, arr_id_reshaped), axis=1)

# %%
index_mask = np.where(clustering_model.labels == prediction[0])[0]
filtered_arr = combined_array[index_mask]

# %%
filtered_arr[:,0:3]
# Out:
# array([[0.035943967838919705, 0.70469404866273, 0.5570870001332336],
#        [1.5640388327239463, 1.4259073639147242, -2.031124789434123],
#        [0.5367195238380779, 0.9093334318138804, 0.7919016883991309],
#        ...,
#        [0.17154562092179693, 1.3783395123491464, 0.1184101086454909],
#        [1.114747888293611, 0.998000286321577, 0.15022199539093864],
#        [0.15189237952884171, 0.6119756328077779, -0.2745819008724956]],
#       dtype=object)

# %%
distances = np.linalg.norm(filtered_arr[:,0:3].astype(float) - reduced_sample, axis=1)
# manhattan_distances = np.sum(np.abs(filtered_arr - reduced_sample), axis=1)
# norm_single = reduced_sample / np.linalg.norm(reduced_sample)
# norm_array = filtered_arr / np.linalg.norm(filtered_arr, axis=1, keepdims=True)

# cosine_similarities = np.dot(norm_array, norm_single)

# cosine_distances = 1 - cosine_similarities
distances = distances.reshape(-1, 1)

# %%
with_distance = np.concatenate((filtered_arr, distances), axis = 1)

# %%
closest_songs = with_distance[with_distance[:, -1].argsort()]

# %%
import pandas as pd
df_songs = pd.read_csv("dataset.csv")

# %%
df_songs_filter = df_songs.loc[df_songs["track_id"].isin(closest_songs[1:90, -2])]

# %%
filtered_df = df_songs_filter.loc[~df_songs_filter.duplicated(subset=["track_name", "artists"])]

# %%
filtered_df
# Out:
#         Unnamed: 0                track_id                     artists  \
# 8202          8202  4mn2kNTqiGLwaUR8JdhJ1l                 The Animals
# 8713          8713  3TETmhGNWOcquUTtcr6RIR                 The Animals
# 11853        11853  1f133Oqpwft2mGNp5cWqaS         Lower Than Atlantis
# 32166        32166  76IijT19KtStPt9ij4nNk5                     Multani
# 34120        34120  0FTfaxNtqgYbqPPcrWQ1IS       Nusrat Fateh Ali Khan
# 40827        40827  12dGdIwsVKWoi9llS1dwNA   Gabriel Guedes de Almeida
# 40978        40978  5URQ1xSOkuIhyP9jjd4tXk              Samuel Messias
# 42148        42148  5KSNy2mfWAKxKhwp6WdmvG                   Mortician
# 54119        54119  5NC4CFZUNpnMlE8OEidYxc                       Ochre
# 56608        56608  1170VohRSx6GwE6QDCHPPH         The Backseat Lovers
# 59208        59208  3HO1JGzpkpKlCscOi9gEZa           AMONGST THE ASHES
# 80700        80700  5lLRB1nnTy1p8nFaH1Vdyf               Mithoon;Papon
# 84806        84806  5FgQkEcqMXCqFdcsEx143b           Aphrodite's Child
# 91653        91653  3z8h0TU7ReDPLIbEnYhWZb                       Queen
# 99961        99961  6HoxQTzbgOilzBMZEYqGw4  Anupam Roy;Rupankar Bagchi
# 112199      112199  6A7FIO2ZmRZf2bnRt8G2AU            Gülden Karaböcek
# 113148      113148  1fcytmf4DjBc7ZkhSPnNIP            Hillsong Worship
# 113193      113193  0WcDc8rCKIxNLXxSmIjTqu            Hillsong Worship
# 113796      113796  3Lca29U4AaObrsNauGFhgK                Chris Tomlin
#
#                                                album_name  \
# 8202                                     The Singles Plus
# 8713     The House of the Rising Sun: Best of The Animals
# 11853                                       Safe In Sound
# 32166                Old World Songs in a New World Order
# 34120                       Shahen-Shah (Real World Gold)
# 40827                           Eterno Presente (Ao Vivo)
# 40978                           Gerado no Altar (Ao Vivo)
# 42148                              Chainsaw Dismemberment
# 54119                              A Midsummer Nice Dream
# 56608                                When We Were Friends
# 59208                                 Agonizing Awakening
# 80700   Hamari Adhuri Kahani (Original Motion Picture ...
# 84806                                               6 6 6
# 91653         Bohemian Rhapsody (The Original Soundtrack)
# 99961                                                 Uma
# 112199  Duyarmısın Feryadımı (Gülden Karaböcek Altın K...
# 113148                                let there be light.
# 113193                                              Awake
# 113796     How Great Is Our God: The Essential Collection
#
#                                               track_name  popularity  \
# 8202                             House of the Rising Sun          75
# 8713                         The House of the Rising Sun          58
# 11853                    I Don't Want to Be Here Anymore          43
# 32166                                             Madira          33
# 34120                Kali Kali Zulfon Ke Phande Nah Dalo          48
# 40827                                 Eu Creio - Ao Vivo          39
# 40978                          Gerado no Altar (Ao Vivo)          38
# 42148                                        Dark Sanity          18
# 54119                                              Yugen          15
# 56608                                         Kilby Girl          78
# 59208                               Exordium of Sickness           0
# 80700                                            Humnava          58
# 84806                                  The Four Horsemen          51
# 91653                                  Bohemian Rhapsody          75
# 99961                                          Jaago Uma          33
# 112199                                  Sevsen Ne Olurdu          45
# 113148                       Behold (Then Sings My Soul)          50
# 113193  From Whom All Blessings Flow (Doxology) - Studio          46
# 113796              How Great Is Our God - World Edition          42
#
#         duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 8202         269906     False         0.316   0.484  ...    -9.110     0
# 8713         269906     False         0.316   0.484  ...    -9.110     0
# 11853        250813     False         0.286   0.350  ...    -8.427     1
# 32166         79830     False         0.542   0.575  ...   -11.764     1
# 34120        706866     False         0.436   0.674  ...   -12.834     1
# 40827        320200     False         0.294   0.451  ...    -8.162     1
# 40978        357954     False         0.328   0.474  ...    -7.972     1
# 42148         87333     False         0.322   0.715  ...   -10.500     1
# 54119        339906     False         0.725   0.730  ...   -10.994     1
# 56608        282205     False         0.329   0.444  ...    -9.973     1
# 59208         80948     False         0.423   0.853  ...   -10.133     1
# 80700        328854     False         0.314   0.478  ...    -7.201     0
# 84806        353426     False         0.294   0.653  ...   -11.520     1
# 91653        354947     False         0.390   0.397  ...    -9.963     0
# 99961        317081     False         0.274   0.605  ...    -6.592     1
# 112199       364333     False         0.345   0.453  ...    -8.274     0
# 113148       406173     False         0.365   0.458  ...    -8.138     1
# 113193       288920     False         0.317   0.459  ...    -7.871     1
# 113796       365134     False         0.356   0.555  ...    -5.658     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 8202         0.0308      0.000334          0.004450    0.0912   0.2990
# 8713         0.0308      0.000334          0.004450    0.0912   0.2990
# 11853        0.0301      0.016500          0.000319    0.1120   0.0871
# 32166        0.0808      0.129000          0.687000    0.2720   0.0747
# 34120        0.0368      0.664000          0.004400    0.2660   0.7520
# 40827        0.0304      0.246000          0.000122    0.0997   0.1410
# 40978        0.0659      0.449000          0.000000    0.0772   0.2360
# 42148        0.0475      0.000004          0.946000    0.1170   0.4000
# 54119        0.0769      0.302000          0.877000    0.3690   0.1110
# 56608        0.0417      0.057800          0.035200    0.1130   0.2250
# 59208        0.0382      0.000440          0.690000    0.1450   0.1070
# 80700        0.0412      0.783000          0.000021    0.1470   0.2760
# 84806        0.0504      0.061200          0.000689    0.1400   0.1850
# 91653        0.0513      0.287000          0.000000    0.2070   0.2460
# 99961        0.0393      0.712000          0.000000    0.0770   0.2060
# 112199       0.0275      0.221000          0.000015    0.3580   0.2810
# 113148       0.0311      0.057600          0.000000    0.3020   0.1140
# 113193       0.0295      0.138000          0.000000    0.1050   0.1130
# 113796       0.0311      0.237000          0.000000    0.1070   0.0759
#
#           tempo  time_signature        track_genre
# 8202    117.363               3              blues
# 8713    117.363               3              blues
# 11853   129.796               4            british
# 32166   170.135               4         electronic
# 34120   138.674               3               folk
# 40827   146.228               4             gospel
# 40978   174.799               4             gospel
# 42148   124.999               4          grindcore
# 54119    98.997               4                idm
# 56608   162.279               4          indie-pop
# 59208    89.980               4            iranian
# 80700   199.631               4           pop-film
# 84806    95.011               4         psych-rock
# 91653   144.031               4               rock
# 99961   167.276               4  singer-songwriter
# 112199   78.538               4            turkish
# 113148   73.991               4        world-music
# 113193  145.045               4        world-music
# 113796   78.104               4        world-music
#
# [19 rows x 21 columns]
